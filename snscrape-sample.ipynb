# %% [markdown]
# ## Sample code for snscrape library

# %%
# !pip install -q snscrape==0.3.4

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Add Google Drive as an accessible path (Optional if you are running from Jupyter Notebook)
from google.colab import drive
drive.mount('/content/drive')

# change path to the designated google drive folder
# otherwise, data will be saved in /content folder which you may have issue locating
# %cd /content/drive/My Drive/Colab Notebooks
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# ##Extracting Tweets based on Keyword

# %%
# set parameters used to retrieve tweets
keyword= 'election'   # you can also include multiple keywords e.g., 'elections AND covid', 'elections OR covid'
from_date = '2020-11-01'
end_date = '2020-11-05'
max_tweet = 1000

# %%
# Creating list to append tweet data to
tweets_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:en since:' +  from_date + ' until:' + end_date + ' -filter:links -filter:replies -filter:retweets').get_items()):
    tweets_list.append([tweet.date,tweet.id,tweet.username,tweet.content])

    if i>max_tweet:
        break
  
# Creating a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime','Tweet Id','Username', 'Text'])
pd.set_option('display.max_colwidth', 150)
tweets_df.head()
# Out:
#                    Datetime             Tweet Id         Username  \
# 0 2020-11-04 23:59:59+00:00  1324139362011865091        7heRealMg
# 1 2020-11-04 23:59:59+00:00  1324139358367051776  ShortsqueezeWSB
# 2 2020-11-04 23:59:58+00:00  1324139356785938435     pearsonsmith
# 3 2020-11-04 23:59:58+00:00  1324139356211175424        _BryanG1_
# 4 2020-11-04 23:59:58+00:00  1324139355657641988          ctovar_
#
#                                                                                                                                                     Text
# 0                                                      The way that the fate of this election is in Nevada’s hands right now has me GOING MAD 😳🤯🥵😖😥😰😳📛🤒🧤
# 1  Funny how y’all think @JoeBiden is going to WIN since he only needs Nevada, FYI Nevada is a PRO-GUN STATE meaning they’re FOR GUNS, and Biden want...
# 2                                                                                      It’s 2020, we all knew the election would be crazy in a 2020 way.
# 3                                                                                                          Nevada gotta stay blue to win the election 😭😭
# 4                                                                                       The internet remains undefeated with all these election memes 😂😂

# %%
tweets_df.shape
# Out:
# (1002, 4)

# %%
# Export tweets to csv file
tweets_df.to_csv(f'{keyword}_tweets.csv')
